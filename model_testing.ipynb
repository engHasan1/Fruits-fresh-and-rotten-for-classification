# %%
import joblib
import pandas as pd

# %%
model=joblib.load('fruit_quality_model.pkl')

# %%
newData = pd.read_csv('new_images_features.csv')

feature_names = [
    "mean_R", "mean_G", "mean_B",
    "std_R", "std_G", "std_B",
    "mean_H", "mean_S", "mean_V",
    "std_H", "std_S", "std_V",
    "dark_ratio",
    "high_saturation_ratio",
    "gray_std",
    "laplacian_var"
]

X_new = newData[feature_names]   
pred = model.predict(X_new)

# %%
pred
# Out:
# array(['freshapples', 'freshbanana', 'freshoranges', 'rottenapples',
#        'rottenbanana', 'rottenoranges'], dtype=object)
